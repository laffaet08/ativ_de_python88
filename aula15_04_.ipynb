# %% [markdown]
# <a href="https://colab.research.google.com/github/laffaet08/ativ_de_python88/blob/main/aula15_04_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "DOIDOKONG"
print(nome.lower())
# Out:
# doidokong

# %%
nome = "doidokong"
print(nome.upper())
# Out:
# DOIDOKONG

# %%
nome = " roman "
print(nome.strip())
# Out:
# roman

# %%
texto = " hey TEJ"
print(texto.replace("TEJ","Suki"))
# Out:
#  hey Suki

# %%
nome = "bryan"
print(len(nome))
# Out:
# 5

# %%
#atividade

nome = " MARIA EDUARDA ALMEIDA "
email = " MARIA.ALMEIDA@EMPRESA.COM "
print(nome.strip())
print(email.strip())
print(nome.lower())
print(email.lower())
print(email.replace("EMPRESA.COM", "GMAIL.COM"))
print (len(nome) - nome.count(" "))
print(nome[1])
print(nome[-2])
# Out:
# MARIA EDUARDA ALMEIDA
# MARIA.ALMEIDA@EMPRESA.COM
#  maria eduarda almeida
#  maria.almeida@empresa.com
#  MARIA.ALMEIDA@GMAIL.COM
# 19
# M
# A

# %% [markdown]
# ATIVIDADE 2

# %%
produto = " NOTEBOOK DELL INSPIRON "
categoria = " INFORMATICA "
codigo = " ABC-123-XYZ "

print(produto.strip())
print(categoria.strip())
print(codigo.strip())
print(produto.lower())
print(categoria.lower())
print(codigo.lower())
print(produto.upper())
print(categoria.upper())
print(codigo.upper())
print(codigo.replace("-", " "))
print(len(produto) - produto.count(" "))
print(produto[1])
print(produto[0:5])
# Out:
# NOTEBOOK DELL INSPIRON
# INFORMATICA
# ABC-123-XYZ
#  notebook dell inspiron
#  informatica
#  abc-123-xyz
#  NOTEBOOK DELL INSPIRON
#  INFORMATICA
#  ABC-123-XYZ
#  ABC 123 XYZ
# 20
# N
#  NOTE
